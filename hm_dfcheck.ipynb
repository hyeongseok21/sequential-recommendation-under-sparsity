# %%
import pandas as pd
import numpy as np
import collections

# %%
pui_filename = 'datasets/hm/purchase_user_item.csv'
pui_df = pd.read_csv(pui_filename, index_col = 0)
pui_df
# Out:
#                                                     user_id   age  \
# 0         00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...  49.0
# 1         00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...  49.0
# 2         00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...  49.0
# 3         00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...  49.0
# 4         00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...  49.0
# ...                                                     ...   ...
# 28575390  ffffd7744cebcf3aca44ae7049d2a94b87074c3d4ffe38...  18.0
# 28575391  ffffd7744cebcf3aca44ae7049d2a94b87074c3d4ffe38...  18.0
# 28575392  ffffd7744cebcf3aca44ae7049d2a94b87074c3d4ffe38...  18.0
# 28575393  ffffd7744cebcf3aca44ae7049d2a94b87074c3d4ffe38...  18.0
# 28575394  ffffd9ac14e89946416d80e791d064701994755c3ab686...  65.0
#
#                                                 postal_code    item_id  \
# 0         52043ee2162cf5aa7ee79974281641c6f11a68d276429a...  625548001
# ...

# %%
len(pui_df['postal_code'].value_counts())
# Out:
# 352336

# %%
pui_df.dropna(axis = 0)
# Out:
#                                                     user_id   age  \
# 0         00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...  49.0
# 1         00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...  49.0
# 2         00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...  49.0
# 3         00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...  49.0
# 4         00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...  49.0
# ...                                                     ...   ...
# 28575390  ffffd7744cebcf3aca44ae7049d2a94b87074c3d4ffe38...  18.0
# 28575391  ffffd7744cebcf3aca44ae7049d2a94b87074c3d4ffe38...  18.0
# 28575392  ffffd7744cebcf3aca44ae7049d2a94b87074c3d4ffe38...  18.0
# 28575393  ffffd7744cebcf3aca44ae7049d2a94b87074c3d4ffe38...  18.0
# 28575394  ffffd9ac14e89946416d80e791d064701994755c3ab686...  65.0
#
#                                                 postal_code    item_id  \
# 0         52043ee2162cf5aa7ee79974281641c6f11a68d276429a...  625548001
# ...

# %%
pui_df['garment_group_no'].astype('category')
# Out:
# 0           1007
# 1           1007
# 2           1007
# 3           1005
# 4           1008
#             ...
# 28575390    1013
# 28575391    1005
# 28575392    1013
# 28575393    1017
# 28575394    1020
# Name: garment_group_no, Length: 28575395, dtype: category
# Categories (21, int64): [1001, 1002, 1003, 1005, ..., 1020, 1021, 1023, 1025]

# %%
pui_df['age'].dtype
# Out:
# dtype('float64')
